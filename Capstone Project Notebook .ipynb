# %% [markdown]
# # CAPSTONE PROJECT :
# ### FINANCE AND RISK ANALYTICS DOMAIN PROJECT

# %% [markdown]
# ###  Problem Statement:
#
# - **Growth of Wealth Management**: The industry has expanded as individuals and businesses seek maximum returns on investments.
# - **Investor Challenges**: Many investors lack the skills or time to identify profitable investment opportunities.
# - **Portfolio Managers**: Professionals who manage investments on behalf of clients in exchange for a commission, handling investment decisions and portfolio management.
# - **Team Effort**: Portfolio managers work with analysts and researchers to understand client needs and design suitable portfolios.
# - **Responsibilities:**
#    - Establish investment strategies.
#    - Select appropriate investments and allocate assets accordingly.
# - **Competition:** Portfolio managers face rivalry from other managers and firms, requiring them to use resources effectively to provide the best solutions.
# - **Our Role:** As associates at an investment firm, we analyze stock portfolios to offer investment management advice based on client requirements.
#
#
#
#
#
#
#
# ### Business Requirement:
#
# - Being a portfolio manager, the task is to provide consultation to two different investors, considered as Private Clients, i.e **Mr Patrick Jyenger and Mr Peter Jyenger** based on their requirements and financial objectives:
#
#
#
#
#    - **The primary goal of this Case Study:**
#
#       - To Suggest a Portfolio of stocks to Mr Patrick Jyenger based on his risk profile to meet his goal on doubling the amount of 500K Dollars in five years of timespan to buy a minoruty stake in Naturo.
#
#      - To provide a High risk stock to Mr Peter Jyenger based on his risk profile to accomplish his goal on earning greater returns for the invested amount of 1 Million Dollars over a five years of timeframe to use it for the expansion of JWW.

# %% [markdown]
# #### First of all we will import all the necessary libraries and warnings:
# - **Numpy** is for solving any numerical part in dataset. It is one of the most important libararies of python
# - **Pandas** is a python library which is used for working with datasets.It's functions are analyzing, cleaning,exploring and manipulating data
# - **Matplotlib** is also a pyhton library, used for understanding the trends and patterns obsereved in given data. It has wide variety of charts and plots to represent data visualization
# - **Seaborn** is python library and it is bulid on the top of matplotlib with more easy functions provided. Seaborn helps you explore and understand your data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
# IMPORT WARNINGS :
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Now we will import our required data to be analyzed-
# - Here,  we have multiple datasets of different companies stocks
# - First of all, entire data must be merged into a single dataframe with only the required columns.
# - There are  24 stocks of leading companies listed in New York Stock Exchange

# %% [markdown]
# #### Import the ANNEXURE:
# - Top 24 companies listed in New-York Stock Exchange

# %%
Annexure = pd.read_csv('Annexure.csv')
Annexure
# Out:
#    Ticker         Industry                 Company Name
# 0     AAL         Aviation  American Airlines Group Inc
# 1    ALGT         Aviation     Allegiant Travel Company
# 2     ALK         Aviation         Alaska Air Group Inc
# 3     DAL         Aviation          Delta Air Lines Inc
# 4      HA         Aviation        Hawaiian Holdings Inc
# 5     LUV         Aviation        Southwest Airlines Co
# 6     BCS          Finance                     Barclays
# 7      CS          Finance                Credit Suisse
# 8      DB          Finance                Deutsche Bank
# 9      GS          Finance                Goldman Sachs
# 10     MS          Finance               Morgan Stanley
# 11    WFC          Finance                 Wells Fargo
# 12    JNJ       Healthcare            Johnson & Johnson
# 13    MRK       Healthcare            Merck and CO inc.
# 14    PFE       Healthcare                   Pfizer inc
# 15   UNH        Healthcare        UnitedHealthGroup Inc
# ...

# %% [markdown]
# ### Importing STOCKS:

# %%
SP500 = pd.read_csv('S&P500.csv')
SP500.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  01-10-2010  1143.489990  1150.300049  1139.420044  1146.239990
# 1  04-10-2010  1144.959961  1148.160034  1131.869995  1137.030029
# 2  05-10-2010  1140.680054  1162.760010  1140.680054  1160.750000
# 3  06-10-2010  1159.810059  1162.329956  1154.849976  1159.969971
# 4  07-10-2010  1161.569946  1163.869995  1151.410034  1158.060059
#
#      Adj Close      Volume
# 0  1146.239990  4298910000
# 1  1137.030029  3604110000
# 2  1160.750000  4068840000
# 3  1159.969971  4073160000
# 4  1158.060059  3910550000

# %%
# Aviation
AAL  = pd.read_csv('AAL.csv')
ALGT = pd.read_csv('ALGT.csv')
ALK  = pd.read_csv('ALK.csv')
DAL  = pd.read_csv('DAL.csv')
HA   = pd.read_csv('HA.csv')
LUV  = pd.read_csv('LUV.csv')

# Finance
BCS = pd.read_csv('BCS.csv')
CS  = pd.read_csv('CS.csv')
DB  = pd.read_csv('DB.csv')
GS  = pd.read_csv('GS.csv')
MS  = pd.read_csv('MS.csv')
WFC = pd.read_csv('WFC.csv')

# Pharma_healthcare
BHC   = pd.read_csv('BHC.csv')
JNJ   = pd.read_csv('JNJ.csv')
MRK   = pd.read_csv('MRK.csv')
PFE   = pd.read_csv('PFE.csv')           
RHHBY = pd.read_csv('RHHBY.csv')
UNH   = pd.read_csv('UNH.csv')

# Technology
AAPL = pd.read_csv('AAPL.csv')
AMZN = pd.read_csv('AMZN.csv')
FB   = pd.read_csv('FB.csv')
GOOG = pd.read_csv('GOOG.csv')
IBM  = pd.read_csv('IBM.csv')
MSFT = pd.read_csv('MSFT.csv')

# %% [markdown]
# ### Renaming the 'close' column with the name of the stock

# %%
# S&P500
SP500 = SP500.rename(columns = {'Close':'S&P500'})

# Aviation
AAL = AAL.rename(columns = {'Close':'AAL'})
ALGT = ALGT.rename(columns = {'Close':'ALGT'})
ALK = ALK.rename(columns = {'Close':'ALK'})
DAL = DAL.rename(columns = {'Close':'DAL'})
HA = HA.rename(columns = {'Close':'HA'})
LUV = LUV.rename(columns = {'Close':'LUV'})

# Finance
BCS = BCS.rename(columns = {'Close':'BCS'})
CS = CS.rename(columns = {'Close':'CS'})
DB = DB.rename(columns = {'Close':'DB'})
GS = GS.rename(columns = {'Close':'GS'})
MS = MS.rename(columns = {'Close':'MS'})
WFC = WFC.rename(columns = {'Close':'WFC'})

# Pharma_healthcare
BHC = BHC.rename(columns = {'Close':'BHC'})
JNJ = JNJ.rename(columns = {'Close':'JNJ'})
MRK = MRK.rename(columns = {'Close':'MRK'})
PFE = PFE.rename(columns = {'Close':'PFE'})
RHHBY = RHHBY.rename(columns = {'Close':'RHHBY'})
UNH = UNH.rename(columns = {'Close':'UNH'})

# Technology
AAPL = AAPL.rename(columns = {'Close':'AAPL'})
AMZN = AMZN.rename(columns = {'Close':'AMZN'})
FB = FB.rename(columns = {'Close':'FB'})
GOOG = GOOG.rename(columns = {'Close':'GOOG'})
IBM = IBM.rename(columns = {'Close':'IBM'})
MSFT = MSFT.rename(columns = {'Close':'MSFT'})

# %% [markdown]
# ## Deleting unnecessary columns from all the stocks
#
# #### Only the 'Date' and 'Close price' columns are used in the analysis. As a result, only these two columns are recorded.

# %%
# S&P500
SP500 = SP500[['Date','S&P500']]

# Aviation
AAL = AAL[['Date','AAL']]
ALGT = ALGT[['Date','ALGT']]
ALK = ALK[['Date','ALK']]
DAL = DAL[['Date','DAL']]
HA = HA[['Date','HA']]
LUV = LUV[['Date','LUV']]

# Finance
BCS = BCS[['Date','BCS']]
CS = CS[['Date','CS']]
DB = DB[['Date','DB']]
GS = GS[['Date','GS']]
MS = MS[['Date','MS']]
WFC = WFC[['Date','WFC']]

# Pharma_healthcare
BHC = BHC[['Date','BHC']]
JNJ = JNJ[['Date','JNJ']]
MRK = MRK[['Date','MRK']]
PFE = PFE[['Date','PFE']]
RHHBY = RHHBY[['Date','RHHBY']]
UNH = UNH[['Date','UNH']]

# Technology
AAPL = AAPL[['Date','AAPL']]
AMZN = AMZN[['Date','AMZN']]
FB = FB[['Date','FB']]
GOOG = GOOG[['Date','GOOG']]
IBM = IBM[['Date','IBM']]
MSFT = MSFT[['Date','MSFT']]

# %% [markdown]
# ### Combining all the stocks
# - Merging all the stocks into a single dataframe

# %%
# S&P500
data = pd.merge(SP500, AAL, how='inner', on='Date')

# Aviation
data = pd.merge(data, ALGT, how='inner', on='Date')
data = pd.merge(data, ALK, how='inner', on='Date')
data = pd.merge(data, DAL, how='inner', on='Date')
data = pd.merge(data, HA, how='inner', on='Date')
data = pd.merge(data, LUV, how='inner', on='Date')

# Finance
data = pd.merge(data, BCS, how='inner', on='Date')
data = pd.merge(data, CS, how='inner', on='Date')
data = pd.merge(data, DB, how='inner', on='Date')
data = pd.merge(data, GS, how='inner', on='Date')
data = pd.merge(data, MS, how='inner', on='Date')
data = pd.merge(data, WFC, how='inner', on='Date')

# Pharma_healthcare
data = pd.merge(data, BHC, how='inner', on='Date')
data = pd.merge(data, JNJ, how='inner', on='Date')
data = pd.merge(data, MRK, how='inner', on='Date')
data = pd.merge(data, PFE, how='inner', on='Date')
data = pd.merge(data, RHHBY, how='inner', on='Date')
data = pd.merge(data, UNH, how='inner', on='Date')

# Technology
data = pd.merge(data, AAPL, how='inner', on='Date')
data = pd.merge(data, AMZN, how='inner', on='Date')
data = pd.merge(data, FB, how='inner', on='Date')
data = pd.merge(data, GOOG, how='inner', on='Date')
data = pd.merge(data, IBM, how='inner', on='Date')
data = pd.merge(data, MSFT, how='inner', on='Date')

# %% [markdown]
# ## General overview of dataset OR Data Preparation:

# %%
data.head()
# Out:
#          Date       S&P500    AAL       ALGT        ALK    DAL    HA   LUV  \
# 0  18-05-2012  1295.219971  10.06  62.310001  16.170000  10.14  5.28  8.15
# 1  21-05-2012  1315.989990  10.71  62.660000  16.379999  10.58  5.32  8.34
# 2  22-05-2012  1316.630005  10.62  62.349998  16.225000  10.54  5.23  8.27
# 3  23-05-2012  1318.859985  11.00  62.990002  16.115000  10.74  5.38  8.36
# 4  24-05-2012  1320.680054  12.16  64.250000  16.920000  11.27  5.68  8.74
#
#          BCS         CS  ...        MRK        PFE      RHHBY        UNH  \
# 0  10.285714  19.169922  ...  37.820000  22.570000  20.160000  53.990002
# 1  10.672812  19.541016  ...  37.599998  22.540001  20.389999  55.549999
# 2  10.857142  19.863281  ...  37.459999  22.370001  20.430000  55.720001
# 3  10.737328  19.765625  ...  37.340000  22.090000  20.075001  55.360001
# 4  10.746544  19.658203  ...  37.599998  22.139999  19.855000  56.220001
#
#         AAPL        AMZN         FB        GOOG         IBM       MSFT
# ...

# %%
# shape of dataset :
data.shape
# Out:
# (2106, 26)

# %%
# datatypes: 
data.dtypes
# Out:
# Date       object
# S&P500    float64
# AAL       float64
# ALGT      float64
# ALK       float64
# DAL       float64
# HA        float64
# LUV       float64
# BCS       float64
# CS        float64
# DB        float64
# GS        float64
# MS        float64
# WFC       float64
# BHC       float64
# JNJ       float64
# MRK       float64
# PFE       float64
# RHHBY     float64
# UNH       float64
# AAPL      float64
# AMZN      float64
# FB        float64
# GOOG      float64
# IBM       float64
# MSFT      float64
# dtype: object

# %%
# this describes the numerical columns:
data.describe()
# Out:
#             S&P500          AAL         ALGT          ALK          DAL  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean   2273.892283    33.552859   133.642911    56.696432    40.479141
# std     534.027978    13.036814    35.668011    20.649972    14.673069
# min    1278.040039     9.040000    62.259998    16.115000     8.550000
# 25%    1895.847473    22.792499   109.180000    38.462500    30.582500
# 50%    2132.765014    36.365000   136.060005    62.570002    45.315000
# 75%    2736.487549    43.465001   159.899994    69.169998    51.552501
# max    3580.840088    58.470001   233.979996   100.239998    63.160000
#
#                 HA          LUV          BCS           CS           DB  ...  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000  ...
# mean     26.177854    38.977840    11.822157    19.199134    23.418093  ...
# std      14.808009    16.480813     3.736298     7.109165    13.237359  ...
# ...

# %% [markdown]
# # Handling Irregualrities:-
# - datatypes
# - fix rows and columns
# - imputing columns
# - outliers
# - standarize
# - filter data
#
#
# #### 1. Datatypes:

# %%
data.dtypes
# Out:
# Date       object
# S&P500    float64
# AAL       float64
# ALGT      float64
# ALK       float64
# DAL       float64
# HA        float64
# LUV       float64
# BCS       float64
# CS        float64
# DB        float64
# GS        float64
# MS        float64
# WFC       float64
# BHC       float64
# JNJ       float64
# MRK       float64
# PFE       float64
# RHHBY     float64
# UNH       float64
# AAPL      float64
# AMZN      float64
# FB        float64
# GOOG      float64
# IBM       float64
# MSFT      float64
# dtype: object

# %% [markdown]
# ##### here we can see that the "date" column is in object datatype, so we will convert it:

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')

# %%
# got all the correct datatypes of columns :
data.dtypes
# Out:
# Date      datetime64[ns]
# S&P500           float64
# AAL              float64
# ALGT             float64
# ALK              float64
# DAL              float64
# HA               float64
# LUV              float64
# BCS              float64
# CS               float64
# DB               float64
# GS               float64
# MS               float64
# WFC              float64
# BHC              float64
# JNJ              float64
# MRK              float64
# PFE              float64
# RHHBY            float64
# UNH              float64
# AAPL             float64
# AMZN             float64
# FB               float64
# GOOG             float64
# IBM              float64
# MSFT             float64
# dtype: object

# %% [markdown]
# ### 2. Handling missing values:
# - CALCULATE THE MISSING VALUE % OF EACH COLUMN: -

# %%
# Column wise Null Values % : 

null_percent = pd.DataFrame(round((data.isnull().sum())*100/data.shape[0],2)).reset_index()
null_percent.columns=['Column Name', 'Null Value %']
null_score = pd.DataFrame(data.isnull().sum()).reset_index()
null_score.columns = ['Column Name', 'Null Values']
null_stocks = pd.merge(null_score, null_percent, on='Column Name')
null_stocks
# Out:
#    Column Name  Null Values  Null Value %
# 0         Date            0           0.0
# 1       S&P500            0           0.0
# 2          AAL            0           0.0
# 3         ALGT            0           0.0
# 4          ALK            0           0.0
# 5          DAL            0           0.0
# 6           HA            0           0.0
# 7          LUV            0           0.0
# 8          BCS            0           0.0
# 9           CS            0           0.0
# 10          DB            0           0.0
# 11          GS            0           0.0
# 12          MS            0           0.0
# 13         WFC            0           0.0
# 14         BHC            0           0.0
# 15         JNJ            0           0.0
# 16         MRK            0           0.0
# 17         PFE            0           0.0
# 18       RHHBY            0           0.0
# 19         UNH            0           0.0
# 20        AAPL            0           0.0
# ...

# %% [markdown]
# ## observe the columns having missing values > 40%-
# - so we can see here, there is no columns having > 40 % missing values.
# #### For columns having missing value as "NaN" OR <13%:
#
# - we use the imputation method for NaN values imputation includes-
#    - mean (for numerical columns)
#    - mode (for numerical columns)
#    - median (for categorical columns)
#
# - we can replace all the values with these imputation method which columns are having values > 13% i.e. **FB**
#
#
# #### IMPUTING THE MISSING VALUES WITH (MEAN METHOD):

# %%
data['FB'].fillna(data['FB'].mean(), inplace=True)
data
# Out:
#            Date       S&P500    AAL        ALGT        ALK        DAL     HA  \
# 0    2012-05-18  1295.219971  10.06   62.310001  16.170000  10.140000   5.28
# 1    2012-05-21  1315.989990  10.71   62.660000  16.379999  10.580000   5.32
# 2    2012-05-22  1316.630005  10.62   62.349998  16.225000  10.540000   5.23
# 3    2012-05-23  1318.859985  11.00   62.990002  16.115000  10.740000   5.38
# 4    2012-05-24  1320.680054  12.16   64.250000  16.920000  11.270000   5.68
# ...         ...          ...    ...         ...        ...        ...    ...
# 2101 2020-09-24  3246.590088  11.77  121.500000  35.700001  29.010000  12.40
# 2102 2020-09-25  3298.459961  12.29  123.760002  36.700001  29.780001  12.80
# 2103 2020-09-28  3351.600098  12.76  127.110001  37.540001  31.340000  13.38
# 2104 2020-09-29  3335.469971  12.25  121.089996  36.669998  30.610001  12.86
# 2105 2020-09-30  3363.000000  12.29  119.800003  36.630001  30.580000  12.89
#
# ...

# %%
stocks_df=data.isnull().mean().round(5)*100
stocks_df
# Out:
# Date      0.0
# S&P500    0.0
# AAL       0.0
# ALGT      0.0
# ALK       0.0
# DAL       0.0
# HA        0.0
# LUV       0.0
# BCS       0.0
# CS        0.0
# DB        0.0
# GS        0.0
# MS        0.0
# WFC       0.0
# BHC       0.0
# JNJ       0.0
# MRK       0.0
# PFE       0.0
# RHHBY     0.0
# UNH       0.0
# AAPL      0.0
# AMZN      0.0
# FB        0.0
# GOOG      0.0
# IBM       0.0
# MSFT      0.0
# dtype: float64

# %% [markdown]
# ### Handling the rows and columns:
#
# #### Set the DATE Column as INDEX :

# %%
data =data.set_index('Date')
data.head()
# Out:
#                  S&P500    AAL       ALGT        ALK    DAL    HA   LUV  \
# Date
# 2012-05-18  1295.219971  10.06  62.310001  16.170000  10.14  5.28  8.15
# 2012-05-21  1315.989990  10.71  62.660000  16.379999  10.58  5.32  8.34
# 2012-05-22  1316.630005  10.62  62.349998  16.225000  10.54  5.23  8.27
# 2012-05-23  1318.859985  11.00  62.990002  16.115000  10.74  5.38  8.36
# 2012-05-24  1320.680054  12.16  64.250000  16.920000  11.27  5.68  8.74
#
#                   BCS         CS         DB  ...        MRK        PFE  \
# Date                                         ...
# 2012-05-18  10.285714  19.169922  34.370228  ...  37.820000  22.570000
# 2012-05-21  10.672812  19.541016  35.505726  ...  37.599998  22.540001
# 2012-05-22  10.857142  19.863281  35.410305  ...  37.459999  22.370001
# 2012-05-23  10.737328  19.765625  35.381680  ...  37.340000  22.090000
# 2012-05-24  10.746544  19.658203  34.828243  ...  37.599998  22.139999
#
# ...

# %%
#Lets make a copy for the data:

stocks_original = data.copy()

stocks_original.head()
# Out:
#                  S&P500    AAL       ALGT        ALK    DAL    HA   LUV  \
# Date
# 2012-05-18  1295.219971  10.06  62.310001  16.170000  10.14  5.28  8.15
# 2012-05-21  1315.989990  10.71  62.660000  16.379999  10.58  5.32  8.34
# 2012-05-22  1316.630005  10.62  62.349998  16.225000  10.54  5.23  8.27
# 2012-05-23  1318.859985  11.00  62.990002  16.115000  10.74  5.38  8.36
# 2012-05-24  1320.680054  12.16  64.250000  16.920000  11.27  5.68  8.74
#
#                   BCS         CS         DB  ...        MRK        PFE  \
# Date                                         ...
# 2012-05-18  10.285714  19.169922  34.370228  ...  37.820000  22.570000
# 2012-05-21  10.672812  19.541016  35.505726  ...  37.599998  22.540001
# 2012-05-22  10.857142  19.863281  35.410305  ...  37.459999  22.370001
# 2012-05-23  10.737328  19.765625  35.381680  ...  37.340000  22.090000
# 2012-05-24  10.746544  19.658203  34.828243  ...  37.599998  22.139999
#
# ...

# %%
stocks_original.shape
# Out:
# (2106, 25)

# %% [markdown]
# ### Exporting the cleaned data into CSV file:

# %%
data.to_csv('Cleaned_data_final.csv',index=False)

# %% [markdown]
# # Now we will start analysis on Normalized dataset:
# - We have given the data of last 10 years i.e. from 1st October 2010 to 30th September 2020.
# - But we have to do analyse the trend on data of last  **5yrs**
# - It means the Analysis is going to be done on previous 5 years i.e. **1st October 2015 to 30th sep 2020**
# - So, we will slice the data from october 2015
#
#
# #### SLICED DATA:

# %%
data =data['10-01-2015':]
data.head()
# Out:
#                  S&P500        AAL        ALGT        ALK        DAL  \
# Date
# 2015-10-01  1923.819946  39.200001  217.979996  80.230003  45.410000
# 2015-10-02  1951.359985  38.630001  215.589996  79.260002  44.869999
# 2015-10-05  1987.050049  40.189999  216.059998  80.910004  46.959999
# 2015-10-06  1979.920044  38.130001  208.600006  74.529999  45.090000
# 2015-10-07  1995.829956  39.310001  213.839996  75.970001  45.990002
#
#                    HA        LUV    BCS         CS         DB  ...        MRK  \
# Date                                                           ...
# 2015-10-01  24.730000  38.410000  15.01  24.090000  26.520000  ...  49.369999
# 2015-10-02  24.280001  38.380001  15.39  24.639999  27.139999  ...  50.139999
# 2015-10-05  25.500000  39.299999  15.60  25.160000  28.200001  ...  51.230000
# 2015-10-06  24.250000  38.000000  15.55  25.379999  28.400000  ...  49.799999
# 2015-10-07  24.559999  38.709999  15.73  25.320000  28.790001  ...  50.950001
#
# ...

# %% [markdown]
# #### Shape of sliced Data:

# %%
data.shape
# Out:
# (1259, 25)

# %% [markdown]
# ## Save the Cleaned Dataset:

# %%
data.to_csv('Final_Cleaned_Dataset.csv')

# %%
# analyze the numerical columns on cleaned data:
data.describe()
# Out:
#             S&P500          AAL         ALGT          ALK          DAL  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000
# mean   2608.429927    36.393948   144.722939    66.828475    48.221382
# std     394.738078    11.486983    24.906476    15.353956     9.378341
# min    1829.079956     9.040000    66.230003    23.559999    19.190001
# 25%    2264.484986    30.360001   130.075005    61.635000    45.274999
# 50%    2656.300049    37.950001   144.000000    66.150002    50.340000
# 75%    2888.265014    45.105002   162.590004    75.765000    54.744999
# max    3580.840088    58.470001   227.860001   100.239998    63.160000
#
#                 HA          LUV          BCS           CS           DB  ...  \
# count  1259.000000  1259.000000  1259.000000  1259.000000  1259.000000  ...
# mean     35.277379    49.521064     9.315425    14.130778    13.593384  ...
# std      11.350796     8.832897     2.187170     3.239365     5.322866  ...
# ...

# %%
# Here we are using the Minmax Scaler...The default range for the feature returned by MinMaxScaler is 0 to 1.
scaler = MinMaxScaler()

# here we are calculating the values and appling the values of the parameters on the actual data and gives the normalized value
scaled =scaler.fit_transform(data.iloc[:])

# reassigning the tranformed dataset to Normalized_data
data.iloc[:]=scaled

# %%
data.head()
# Out:
#               S&P500       AAL      ALGT       ALK       DAL        HA  \
# Date
# 2015-10-01  0.054083  0.610156  0.938873  0.739045  0.596316  0.311593
# 2015-10-02  0.069804  0.598624  0.924086  0.726395  0.584035  0.302884
# 2015-10-05  0.090178  0.630184  0.926994  0.747913  0.631567  0.326495
# 2015-10-06  0.086108  0.588509  0.880839  0.664710  0.589038  0.302303
# 2015-10-07  0.095190  0.612381  0.913259  0.683490  0.609507  0.308303
#
#                  LUV       BCS        CS        DB  ...       MRK       PFE  \
# Date                                                ...
# 2015-10-01  0.342763  0.933166  0.903059  0.832608  ...  0.017952  0.188839
# 2015-10-02  0.342056  0.964912  0.931571  0.857143  ...  0.035673  0.258737
# 2015-10-05  0.363743  0.982456  0.958528  0.899090  ...  0.060759  0.281285
# 2015-10-06  0.333098  0.978279  0.969933  0.907004  ...  0.027848  0.242390
# 2015-10-07  0.349835  0.993317  0.966822  0.922438  ...  0.054315  0.270575
#
# ...

# %%
data.to_csv('normalized_5_Years_data.csv')

# %% [markdown]
# # Sector Wise Analysis :
#
# ## Aviation sector

# %%
Aviation= data[['S&P500','ALGT','AAL','ALK','DAL','HA','LUV']]
Aviation.head()
# Out:
#               S&P500      ALGT       AAL       ALK       DAL        HA  \
# Date
# 2015-10-01  0.054083  0.938873  0.610156  0.739045  0.596316  0.311593
# 2015-10-02  0.069804  0.924086  0.598624  0.726395  0.584035  0.302884
# 2015-10-05  0.090178  0.926994  0.630184  0.747913  0.631567  0.326495
# 2015-10-06  0.086108  0.880839  0.588509  0.664710  0.589038  0.302303
# 2015-10-07  0.095190  0.913259  0.612381  0.683490  0.609507  0.308303
#
#                  LUV
# Date
# 2015-10-01  0.342763
# 2015-10-02  0.342056
# 2015-10-05  0.363743
# 2015-10-06  0.333098
# 2015-10-07  0.349835

# %%
# Calculate the correlation matrix
corr_matrix = Aviation.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix - Aviation Sector')
plt.show()

# %% [markdown]
# # Insights:
# - S&P500 is not co-related to Aviation Sector.
# - Market took a massive hit in 2020 due to corona pandemic which resulted in a bear market.
# - Even though the market recovered but the Aviation Sector underperformed the market.
# - Well within the Aviation Sector only 3 stocks i.e. Allegiant Travel Company, Delta Airlines, Southwest Airlines.
# - As we can see in the pairplot Allegiant Travel Company has some positive coorelation with Delta Airlines.
# - Also we can see there is some positive coorelation of Delta Airlines with Southwest Airlines.
#
#
# # Finance sector

# %%
# Finance Stocks

Finance_Stocks=data[['S&P500','BCS','CS','DB','GS','MS','WFC']]

Finance_Stocks.head()
# Out:
#               S&P500       BCS        CS        DB        GS        MS  \
# Date
# 2015-10-01  0.054083  0.933166  0.903059  0.832608  0.296583  0.263568
# 2015-10-02  0.069804  0.964912  0.931571  0.857143  0.303735  0.261687
# 2015-10-05  0.090178  0.982456  0.958528  0.899090  0.330395  0.284793
# 2015-10-06  0.086108  0.978279  0.969933  0.907004  0.327650  0.286674
# 2015-10-07  0.095190  0.993317  0.966822  0.922438  0.341449  0.301988
#
#                  WFC
# Date
# 2015-10-01  0.666129
# 2015-10-02  0.661982
# 2015-10-05  0.688479
# 2015-10-06  0.679723
# 2015-10-07  0.683410

# %%
# Calculate the correlation matrix
corr_matrix = Finance_Stocks.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix - Finance Sector')
plt.show()

# %% [markdown]
# # Insights:
# - S&P500 is positively co-related with Finance Sector.
# - Althought market took a massive hit in 2020 due to corona pandemic Morgan Stanley and Goldman Sachs were able to recover back as well as out performed the sector but still majority of stocks have been hit.
# - In the pairplot we can see that Goldman Sachs & Morgan Stanley are highly correlated when compared to others stocks.
#
#
# # Pharma sector:

# %%
# Pharma Stocks
Pharma_Stocks = data[['S&P500','BHC','JNJ','MRK','PFE','RHHBY','UNH']]

Pharma_Stocks.head()
# Out:
#               S&P500       BHC       JNJ       MRK       PFE     RHHBY  \
# Date
# 2015-10-01  0.054083  0.984351  0.000000  0.017952  0.188839  0.333985
# 2015-10-02  0.069804  1.000000  0.012191  0.035673  0.258737  0.338875
# 2015-10-05  0.090178  0.891491  0.025505  0.060759  0.281285  0.344743
# 2015-10-06  0.086108  0.906104  0.004010  0.027848  0.242390  0.349144
# 2015-10-07  0.095190  0.928140  0.029034  0.054315  0.270575  0.301222
#
#                  UNH
# Date
# 2015-10-01  0.034410
# 2015-10-02  0.044761
# 2015-10-05  0.048585
# 2015-10-06  0.031799
# 2015-10-07  0.033571

# %%
# Calculate the correlation matrix
corr_matrix = Pharma_Stocks.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix - Aviation Sector')
plt.show()

# %% [markdown]
# # Insights:
# - S&P500 is positively co-related with Health and Pharma Sector(JNJ, MRK, UNH).
# - During the pandemic health and pharma and technology sector showed rapid growth after the market crash in comparison to other industries.
# - From past 5 years we can see that Bausch Health Companies inc has not seen any growth.
# - Overall the health and pharma sector is strong compared to S&P500.
#
#
# # Technology stocks:

# %%
# Technology Stocks
Technology_Stocks = data[['S&P500','AAPL','AMZN','FB','GOOG','IBM','MSFT']]
Technology_Stocks.tail()
# Out:
#               S&P500      AAPL      AMZN        FB      GOOG       IBM  \
# Date
# 2020-09-24  0.809192  0.767373  0.832209  0.744647  0.731430  0.267493
# 2020-09-25  0.838802  0.803755  0.856915  0.769487  0.746354  0.277357
# 2020-09-28  0.869137  0.827770  0.882796  0.778879  0.763865  0.309245
# 2020-09-29  0.859929  0.819974  0.873230  0.802216  0.768172  0.300184
# 2020-09-30  0.875645  0.835387  0.874493  0.802733  0.768413  0.308557
#
#                 MSFT
# Date
# 2020-09-24  0.847840
# 2020-09-25  0.872594
# 2020-09-28  0.881255
# 2020-09-29  0.869600
# 2020-09-30  0.886014

# %%
# Calculate the correlation matrix
corr_matrix = Technology_Stocks.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix - Aviation Sector')
plt.show()

# %% [markdown]
# # Insights:
# - S&P500 is strongly co-related with Technology Sector(AMZN, FB, MSFT, GOOG, AAPL).
# - When compared to other sectors during the pandemic Tech sector was one of few sectors to bounce back sharply.
# - Except for IBM all the other stocks are out performing the market.
# - Also all the stocks except for IBM are strongly co-related with each other.
#
#
# # KEY METRICS:
#
#
# ## Daily Returns
#
# - For calculating the daily returns we will use some formulas and Pandas built in function which is known as pct_change.
# - Using this we will be able to calculate the simple returns for each day and each stock.

# %%
stocks_original.head()
# Out:
#                  S&P500    AAL       ALGT        ALK    DAL    HA   LUV  \
# Date
# 2012-05-18  1295.219971  10.06  62.310001  16.170000  10.14  5.28  8.15
# 2012-05-21  1315.989990  10.71  62.660000  16.379999  10.58  5.32  8.34
# 2012-05-22  1316.630005  10.62  62.349998  16.225000  10.54  5.23  8.27
# 2012-05-23  1318.859985  11.00  62.990002  16.115000  10.74  5.38  8.36
# 2012-05-24  1320.680054  12.16  64.250000  16.920000  11.27  5.68  8.74
#
#                   BCS         CS         DB  ...        MRK        PFE  \
# Date                                         ...
# 2012-05-18  10.285714  19.169922  34.370228  ...  37.820000  22.570000
# 2012-05-21  10.672812  19.541016  35.505726  ...  37.599998  22.540001
# 2012-05-22  10.857142  19.863281  35.410305  ...  37.459999  22.370001
# 2012-05-23  10.737328  19.765625  35.381680  ...  37.340000  22.090000
# 2012-05-24  10.746544  19.658203  34.828243  ...  37.599998  22.139999
#
# ...

# %%
daily_return=stocks_original.copy()

# %%
# Now we will be taking the data of the last 5 years and do the cumulative daily returns
daily_return = daily_return['10-01-2015':]

daily_return.head()
# Out:
#                  S&P500        AAL        ALGT        ALK        DAL  \
# Date
# 2015-10-01  1923.819946  39.200001  217.979996  80.230003  45.410000
# 2015-10-02  1951.359985  38.630001  215.589996  79.260002  44.869999
# 2015-10-05  1987.050049  40.189999  216.059998  80.910004  46.959999
# 2015-10-06  1979.920044  38.130001  208.600006  74.529999  45.090000
# 2015-10-07  1995.829956  39.310001  213.839996  75.970001  45.990002
#
#                    HA        LUV    BCS         CS         DB  ...        MRK  \
# Date                                                           ...
# 2015-10-01  24.730000  38.410000  15.01  24.090000  26.520000  ...  49.369999
# 2015-10-02  24.280001  38.380001  15.39  24.639999  27.139999  ...  50.139999
# 2015-10-05  25.500000  39.299999  15.60  25.160000  28.200001  ...  51.230000
# 2015-10-06  24.250000  38.000000  15.55  25.379999  28.400000  ...  49.799999
# 2015-10-07  24.559999  38.709999  15.73  25.320000  28.790001  ...  50.950001
#
# ...

# %%
# Percentage change between the current and a prior element
for i in list(daily_return.columns[:]):
    daily_return[i]=daily_return[i].pct_change(1)

# %% [markdown]
# - Pct_change:
#     - gives the % change b/w current and previous values
#     - often used to measure stock returns over time.

# %%
# Lets Calculate the cumulative daily returns

df_cum_daily_return = (1 + daily_return).cumprod() - 1

df_cum_daily_return.tail()
# Out:
#               S&P500       AAL      ALGT       ALK       DAL        HA  \
# Date
# 2020-09-24  0.687575 -0.699745 -0.442609 -0.555029 -0.361154 -0.498585
# 2020-09-25  0.714537 -0.686480 -0.432241 -0.542565 -0.344197 -0.482410
# 2020-09-28  0.742159 -0.674490 -0.416873 -0.532095 -0.309844 -0.458957
# 2020-09-29  0.733775 -0.687500 -0.444490 -0.542939 -0.325919 -0.479984
# 2020-09-30  0.748085 -0.686480 -0.450408 -0.543438 -0.326580 -0.478771
#
#                  LUV       BCS        CS        DB  ...       MRK       PFE  \
# Date                                                ...
# 2020-09-24 -0.040354 -0.683544 -0.600664 -0.694193  ...  0.684221  0.123116
# 2020-09-25 -0.034106 -0.686875 -0.606476 -0.698341  ...  0.679765  0.132224
# 2020-09-28 -0.004426 -0.667555 -0.589041 -0.682127  ...  0.676322  0.142902
# 2020-09-29 -0.020828 -0.669554 -0.591947 -0.688160  ...  0.658902  0.135992
# 2020-09-30 -0.023692 -0.666223 -0.586135 -0.683258  ...  0.680170  0.152638
#
# ...

# %% [markdown]
# - **cumulative daily returns:**
#     - It multiplies the daily returns over time, giving you the total return from the starting point to the current date.

# %%
# As we have calculated returns the first row for Returns and CumReturns will be null 
# We will be Deleting the null rows as they are not relevant for our further calculations

daily_return.dropna(axis = 0, inplace = True)
df_cum_daily_return.dropna(axis = 0, inplace = True)

# %% [markdown]
# - why we perfrom this above step:
#     - cleaning the dataset by removing any rows where the values for daily returns or cumulative daily returns are **"NULL" or NaN.**
#     - prepares it for further analysis, ensuring all remaining **rows contain valid data for calculations.**

# %%
df_cum_daily_return.tail()
# Out:
#               S&P500       AAL      ALGT       ALK       DAL        HA  \
# Date
# 2020-09-24  0.687575 -0.699745 -0.442609 -0.555029 -0.361154 -0.498585
# 2020-09-25  0.714537 -0.686480 -0.432241 -0.542565 -0.344197 -0.482410
# 2020-09-28  0.742159 -0.674490 -0.416873 -0.532095 -0.309844 -0.458957
# 2020-09-29  0.733775 -0.687500 -0.444490 -0.542939 -0.325919 -0.479984
# 2020-09-30  0.748085 -0.686480 -0.450408 -0.543438 -0.326580 -0.478771
#
#                  LUV       BCS        CS        DB  ...       MRK       PFE  \
# Date                                                ...
# 2020-09-24 -0.040354 -0.683544 -0.600664 -0.694193  ...  0.684221  0.123116
# 2020-09-25 -0.034106 -0.686875 -0.606476 -0.698341  ...  0.679765  0.132224
# 2020-09-28 -0.004426 -0.667555 -0.589041 -0.682127  ...  0.676322  0.142902
# 2020-09-29 -0.020828 -0.669554 -0.591947 -0.688160  ...  0.658902  0.135992
# 2020-09-30 -0.023692 -0.666223 -0.586135 -0.683258  ...  0.680170  0.152638
#
# ...

# %% [markdown]
# ### Last record of the dataframe multiplied by 100 is giving us the percentage change of the stock prices for our entire period

# %%
#first we will select the last row and assigning it to a new data frame
Cum_daily_return = df_cum_daily_return.iloc[:, :].tail(1)

# rounding off the values by mulitplying with 100
Cum_daily_return = Cum_daily_return * 100

# lets check the dataframe
Cum_daily_return
# Out:
#                S&P500       AAL       ALGT        ALK        DAL         HA  \
# Date
# 2020-09-30  74.808459 -68.64796 -45.040827 -54.343762 -32.658005 -47.877072
#
#                  LUV        BCS         CS         DB  ...        MRK  \
# Date                                                   ...
# 2020-09-30 -2.369175 -66.622252 -58.613533 -68.325792  ...  68.017012
#
#                   PFE      RHHBY         UNH        AAPL       AMZN  \
# Date
# 2020-09-30  15.263822  28.868151  167.361278  322.741369  504.68777
#
#                     FB       GOOG        IBM        MSFT
# Date
# 2020-09-30  187.960421  140.40963 -15.265686  371.486208
#
# [1 rows x 25 columns]

# %%
# reseting the index
Cum_daily_return = Cum_daily_return.reset_index()

# transposing the dataframe 
Cum_daily_return = Cum_daily_return.transpose()

# Removing the date row & selecting only the stocks as per our requirement
Cum_daily_return = Cum_daily_return[1:]

# Renaming the column from Zero to Cumulative Returns
Cum_daily_return = Cum_daily_return.rename(columns = {0: 'Cumulative Returns'}, inplace = False)

# Sorting the values by descending order
Cum_daily_return = Cum_daily_return.sort_values('Cumulative Returns', ascending = False)

# checking the dataframe
Cum_daily_return
# Out:
#        Cumulative Returns
# AMZN            504.68777
# MSFT           371.486208
# AAPL           322.741369
# FB             187.960421
# UNH            167.361278
# GOOG            140.40963
# S&P500          74.808459
# MRK             68.017012
# JNJ             59.793934
# MS              53.492057
# RHHBY           28.868151
# PFE             15.263822
# GS              14.174524
# LUV             -2.369175
# IBM            -15.265686
# DAL            -32.658005
# ALGT           -45.040827
# HA             -47.877072
# WFC            -54.296267
# ALK            -54.343762
# CS             -58.613533
# BCS            -66.622252
# DB             -68.325792
# AAL             -68.64796
# BHC            -91.347439

# %% [markdown]
# #### changing the datatype to float from object so that we can round it off

# %%
# changing the datatype to float from object so that we can round it off
Cum_daily_return['Cumulative Returns'] = Cum_daily_return['Cumulative Returns'].astype(float, errors = 'raise')

# round off the values by 2 decimal points for easy refernce
Cum_daily_return = round(Cum_daily_return['Cumulative Returns'], 2)

# checking the dataframe
Cum_daily_return
# Out:
# AMZN      504.69
# MSFT      371.49
# AAPL      322.74
# FB        187.96
# UNH       167.36
# GOOG      140.41
# S&P500     74.81
# MRK        68.02
# JNJ        59.79
# MS         53.49
# RHHBY      28.87
# PFE        15.26
# GS         14.17
# LUV        -2.37
# IBM       -15.27
# DAL       -32.66
# ALGT      -45.04
# HA        -47.88
# WFC       -54.30
# ALK       -54.34
# CS        -58.61
# BCS       -66.62
# DB        -68.33
# AAL       -68.65
# BHC       -91.35
# Name: Cumulative Returns, dtype: float64

# %% [markdown]
# **When calculated the cummulative daily returns we found out that :**
#
# - Amazon
# - Microsoft
# - Apple
#
# **are the highest return stocks followed by FACEBOOK, GOOGLE and UnitedHealthGroup Inc**
#
# ## Calculation of Sharpe Ratio, Annual Risk & Annual Returns

# %%
#Checking the stats of the data:

daily_return.describe()
# Out:
#             S&P500          AAL         ALGT          ALK          DAL  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean      0.000517    -0.000336    -0.000047    -0.000256     0.000042
# std       0.012080     0.034725     0.029101     0.026907     0.026478
# min      -0.119841    -0.252246    -0.283300    -0.232385    -0.259924
# 25%      -0.002938    -0.013623    -0.011305    -0.010721    -0.009714
# 50%       0.000682    -0.000480    -0.000363     0.000206     0.000783
# 75%       0.005213     0.013233     0.011630     0.010619     0.009781
# max       0.093828     0.410970     0.292428     0.203079     0.210171
#
#                 HA          LUV          BCS           CS           DB  ...  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000  ...
# mean      0.000034     0.000245    -0.000548    -0.000437    -0.000529  ...
# std       0.033132     0.022913     0.025119     0.022842     0.027743  ...
# ...

# %%
#Lets calculate mean and standard deviation of all the stocks:
df_daily_return = daily_return.describe()[1:8].T.sort_values('mean', ascending = False) # sorting the values by mean

# dropping the unnecessary columns:
df = df_daily_return.drop(['25%', '50%', '75%'], axis = 1)

# Renaming the columns names 
df = df.rename(columns = {'mean': 'Avg Daily Returns', 'std':'Risk', "min": "Min", "max" : "Max" }, inplace = False)

# lets check the dataframe
df
# Out:
#         Avg Daily Returns      Risk       Min       Max
# AMZN             0.001611  0.018969 -0.079221  0.132164
# MSFT             0.001387  0.017539 -0.147390  0.142169
# AAPL             0.001322  0.018729 -0.128647  0.119808
# FB               0.001050  0.020354 -0.189609  0.155214
# UNH              0.000941  0.017810 -0.172769  0.127989
# GOOG             0.000834  0.016520 -0.111008  0.104485
# MS               0.000578  0.021810 -0.156000  0.197700
# S&P500           0.000517  0.012080 -0.119841  0.093828
# MRK              0.000511  0.014067 -0.088990  0.104080
# JNJ              0.000451  0.012459 -0.100379  0.079977
# GS               0.000303  0.019899 -0.127053  0.175803
# RHHBY            0.000293  0.013514 -0.089609  0.130118
# LUV              0.000245  0.022913 -0.151094  0.144441
# PFE              0.000209  0.013826 -0.077346  0.089607
# DAL              0.000042  0.026478 -0.259924  0.210171
# HA               0.000034  0.033132 -0.264971  0.245837
# ...

# %% [markdown]
# ## Annualized daily stock return :

# %%
# Lets calculate Annualized Returns

# As per the industry practice here we take 252 days as the number of working days of a stock market 
df["Annualized_Returns"] = df["Avg Daily Returns"]*252

#Lets calculate Annualized risk

df["Annualized_Risk"] = np.sqrt(252) * df["Risk"]

# Lets Calculate the Sharpe Ratio

# here we are considering the risk free rate as 0.75%
df["Sharpe_Ratio"] = ((df["Annualized_Returns"] - 0.0075) / df["Annualized_Risk"]) / 100 #we have divided by 100 to cancel the roundoff 

# lets see the dataframe
df
# Out:
#         Avg Daily Returns      Risk       Min       Max  Annualized_Returns  \
# AMZN             0.001611  0.018969 -0.079221  0.132164            0.405855
# MSFT             0.001387  0.017539 -0.147390  0.142169            0.349535
# AAPL             0.001322  0.018729 -0.128647  0.119808            0.333182
# FB               0.001050  0.020354 -0.189609  0.155214            0.264524
# UNH              0.000941  0.017810 -0.172769  0.127989            0.237197
# GOOG             0.000834  0.016520 -0.111008  0.104485            0.210194
# MS               0.000578  0.021810 -0.156000  0.197700            0.145536
# S&P500           0.000517  0.012080 -0.119841  0.093828            0.130407
# MRK              0.000511  0.014067 -0.088990  0.104080            0.128832
# JNJ              0.000451  0.012459 -0.100379  0.079977            0.113527
# GS               0.000303  0.019899 -0.127053  0.175803            0.076442
# ...

# %% [markdown]
# ### Converting the columns into % columns:

# %%
# Converting the values in percentage by multiplying by 100:
df = df*100

# round off the values by 2 decimal points:
df = round(df, 2)

# lets check the dataframe
df
# Out:
#         Avg Daily Returns  Risk    Min    Max  Annualized_Returns  \
# AMZN                 0.16  1.90  -7.92  13.22               40.59
# MSFT                 0.14  1.75 -14.74  14.22               34.95
# AAPL                 0.13  1.87 -12.86  11.98               33.32
# FB                   0.10  2.04 -18.96  15.52               26.45
# UNH                  0.09  1.78 -17.28  12.80               23.72
# GOOG                 0.08  1.65 -11.10  10.45               21.02
# MS                   0.06  2.18 -15.60  19.77               14.55
# S&P500               0.05  1.21 -11.98   9.38               13.04
# MRK                  0.05  1.41  -8.90  10.41               12.88
# JNJ                  0.05  1.25 -10.04   8.00               11.35
# GS                   0.03  1.99 -12.71  17.58                7.64
# RHHBY                0.03  1.35  -8.96  13.01                7.38
# LUV                  0.02  2.29 -15.11  14.44                6.16
# ...

# %%
#merging the dataframe with cummilative daily returns dataframe:

df_final = pd.concat([df, Cum_daily_return], axis=1)

df_final
# Out:
#         Avg Daily Returns  Risk    Min    Max  Annualized_Returns  \
# AMZN                 0.16  1.90  -7.92  13.22               40.59
# MSFT                 0.14  1.75 -14.74  14.22               34.95
# AAPL                 0.13  1.87 -12.86  11.98               33.32
# FB                   0.10  2.04 -18.96  15.52               26.45
# UNH                  0.09  1.78 -17.28  12.80               23.72
# GOOG                 0.08  1.65 -11.10  10.45               21.02
# MS                   0.06  2.18 -15.60  19.77               14.55
# S&P500               0.05  1.21 -11.98   9.38               13.04
# MRK                  0.05  1.41  -8.90  10.41               12.88
# JNJ                  0.05  1.25 -10.04   8.00               11.35
# GS                   0.03  1.99 -12.71  17.58                7.64
# RHHBY                0.03  1.35  -8.96  13.01                7.38
# LUV                  0.02  2.29 -15.11  14.44                6.16
# ...

# %% [markdown]
# # Insights:
# - At the end of 5 years we can see that the **top 8 performing stocks** based on Annual Returns:
# - **AMZN** gives 40.59% annual returns
# - **MSFT** gives 34.95% annual returns
# - **AAPL** gives 33.32% annual returns
# - **FB** gives 26.45% annual returns
# - **UNH** gives 23.72% annual returns
# - **GOOG** gives 21.02% annual returns
# - **MS** gives 14.55% annual returns
# - **MRK** gives 12.88% annual returns

# %% [markdown]
# ## Stock prices dispersion from mean :
# - OF TOP - 8 PERFORMING STOCKS

# %%
# Calculate the mean close price
mean_price = data['S&P500'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['S&P500'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='teal')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['AMZN'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['AMZN'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='pink')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['MSFT'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['MSFT'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='green')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['AAPL'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['AAPL'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='yellow')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['FB'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['FB'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='red')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['UNH'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['UNH'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='blue')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['GOOG'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['GOOG'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='purple')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['MS'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['MS'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='brown')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %%
# Calculate the mean close price
mean_price = data['MRK'].mean()

# Calculate dispersion (difference from the mean)
data['dispersion_from_mean'] = data['MRK'] - mean_price

# %%
# Set the plot style
sns.set(style="whitegrid")

# Create the histogram
plt.figure(figsize=(10, 6))
sns.histplot(data['dispersion_from_mean'], bins=10, kde=True, color='orange')

# Add labels and title
plt.xlabel('Dispersion from Mean')
plt.ylabel('Frequency')
plt.title('Stock Price Dispersion from Mean')

# Show the plot
plt.show()

# %% [markdown]
# # Graph reperesentation of data:

# %%
# Line chart showing Cumulative returns of stocks

plt.figure(figsize=(15,5))
sns.lineplot(data=df_final['Cumulative Returns']/100, label="Cumulative Daily Return")
sns.lineplot(data=df_final['Avg Daily Returns'], label="Daily Returns")

# Add label for horizontal axis
plt.xlabel("Stocks")

#rotate the labels
plt.xticks(rotation = 90)

# Add label for horizontal axis
plt.ylabel("Cumulative Vs Daily Return")

plt.show()

# %%
# Line chart showing daily returns of stocks

plt.figure(figsize=(15,5))
sns.lineplot(data=df_final['Avg Daily Returns'], label="Daily Returns")

# Add label for horizontal axis
plt.xlabel("Stocks")

#rotate the labels
plt.xticks(rotation = 90)

# Add label for horizontal axis
plt.ylabel("Daily Returns")

plt.show()

# %%
# Line chart showing Cumulative returns of stocks

plt.figure(figsize=(15,5))
sns.lineplot(data=df_final['Cumulative Returns']/100, label="Cumulative Daily Returns")
sns.lineplot(data=df_final['Sharpe_Ratio'], label="Sharpe_Ratio")

# Add label for horizontal axis
plt.xlabel("Stocks")

#rotate the labels
plt.xticks(rotation = 90)

# Add label for horizontal axis
plt.ylabel("Cumulative Daily Returns Vs Sharpe_Ratio")

plt.show()

# %%
# Line chart showing Cumulative returns of stocks

plt.figure(figsize=(15,5))
sns.lineplot(data=df_final['Cumulative Returns']/100, label="Cumulative Daily Returns")
sns.lineplot(data=df_final['Sharpe_Ratio'], label="Sharpe_Ratio")
sns.lineplot(data=df_final['Risk'], label="Risk")


# Add label for horizontal axis
plt.xlabel("Stocks")

#rotate the labels
plt.xticks(rotation = 90)

# Add label for horizontal axis
plt.ylabel("Cumulative Daily Returns Vs Sharpe_Ratio Vs Risk")

plt.show()

# %%
# Line chart showing Cumulative returns of stocks

plt.figure(figsize=(15,5))
sns.lineplot(data=df_final['Annualized_Risk'], label="Annualized_Risk")
sns.lineplot(data=df_final['Annualized_Returns'], label="Annualized_Returns")


# Add label for horizontal axis
plt.xlabel("Stocks")

#rotate the labels
plt.xticks(rotation = 90)

# Add label for horizontal axis
plt.title("Annualized_Risk Vs Annualized_Returns")

plt.show()

# %% [markdown]
# # PORTFOLIO ANAlYSIS:
#
# ### Mr. Patrick Jyengar Portfolio:
# - According to Mr. Patrick investment needs, he wants to double his investment in the span of 5 years
# - He wants to invest in low risk stocks, which would fetch him decent returns
# - As per profile, the stocks like **JNJ, RHHBY,GOOG** is suitable to invest on.
# - But overall returns with these three stocks wouldn't reach the target what Mr. Patrick investing for. So, one portion of his wealth going to be invested on **MSFT** to gain the desired results
#
# #### Let's calculate the risk and return according to above metioned portfolio:

# %%
# Initial weight for each stock in order
stocks_data = ['MSFT', 'JNJ', 'RHHBY' ,'GOOG']

initial_weight_stocks_df = np.array([0.25, 0.25, 0.25, 0.25])

# %%
# Lets create a dataset for selected stocks
stocks = stocks_original['10-01-2015':]
portfolio = stocks.copy()
portfolio = portfolio[stocks_data]
portfolio.tail()
# Out:
#                   MSFT         JNJ      RHHBY         GOOG
# Date
# 2020-09-24  203.190002  144.669998  44.700001  1428.290039
# 2020-09-25  207.820007  145.660004  44.820000  1444.959961
# 2020-09-28  209.440002  147.110001  44.110001  1464.520020
# 2020-09-29  207.259995  147.059998  43.369999  1469.329956
# 2020-09-30  210.330002  148.880005  42.810001  1469.599976

# %% [markdown]
# ### Stock Return on Daily Basis:

# %%
# Calculating the daily percentage change:

stocks_returns_daily = portfolio.pct_change()
stocks_returns_daily.head()
# Out:
#                 MSFT       JNJ     RHHBY      GOOG
# Date
# 2015-10-01       NaN       NaN       NaN       NaN
# 2015-10-02  0.021520  0.008157  0.003010  0.025553
# 2015-10-05  0.023261  0.008836  0.003601  0.023225
# 2015-10-06  0.002573 -0.014141  0.002691  0.006189
# 2015-10-07  0.001069  0.016699 -0.029228 -0.004772

# %% [markdown]
# ### Average daily Return of Stock:

# %%
# let's calculate the avg daily returns:

avg_stocks_daily_returns = stocks_returns_daily.mean()
avg_stocks_daily_returns
# Out:
# MSFT     0.001387
# JNJ      0.000451
# RHHBY    0.000293
# GOOG     0.000834
# dtype: float64

# %% [markdown]
# ### Risk of Stocks in Portfolio:

# %%
#Calculating Risk of the stocks:

stock_risk= stocks_returns_daily.std()
stock_risk
# Out:
# MSFT     0.017539
# JNJ      0.012459
# RHHBY    0.013514
# GOOG     0.016520
# dtype: float64

# %% [markdown]
# ### Overall risk of stocks in portfolio :

# %%
avg_risk = stock_risk.mean()
avg_risk_per=avg_risk*100
print(round(avg_risk_per,3),"%")
# Out:
# 1.501 %

# %% [markdown]
# ### Daily return from the portfolio:

# %%
# Daily return from the portfolio

stocks_returns_daily['portfolio_daily_return'] = stocks_returns_daily.dot(initial_weight_stocks_df)
stocks_returns_daily.head()
# Out:
#                 MSFT       JNJ     RHHBY      GOOG  portfolio_daily_return
# Date
# 2015-10-01       NaN       NaN       NaN       NaN                     NaN
# 2015-10-02  0.021520  0.008157  0.003010  0.025553                0.014560
# 2015-10-05  0.023261  0.008836  0.003601  0.023225                0.014731
# 2015-10-06  0.002573 -0.014141  0.002691  0.006189               -0.000672
# 2015-10-07  0.001069  0.016699 -0.029228 -0.004772               -0.004058

# %% [markdown]
# ### Total Portfolio Return:

# %%
#Let's calculate the total returns of the portfolio:

allocated_stocks_daily_return = (initial_weight_stocks_df * avg_stocks_daily_returns)

portfolio_return = np.sum(allocated_stocks_daily_return)
portfolio_return*100
# Out:
# 0.07410905572706407

# %% [markdown]
# ### The Average Daily Returns of Portfolio is 0.07%

# %%
# Lets Plot the graph
plt.figure(figsize=(16,8))
stocks_returns_daily['portfolio_daily_return'].plot()
plt.title('Portfolio Daily Returns', fontsize = 20)
plt.legend(loc = 'best', fontsize = 15)
plt.xticks(rotation=0)
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ### Cummulative Return from the Portfolio:

# %%
# Cumulative return from the portfolio

daily_cumulative_return = (1+stocks_returns_daily).cumprod()
daily_cumulative_return.tail(5)
# Out:
#                 MSFT       JNJ     RHHBY      GOOG  portfolio_daily_return
# Date
# 2020-09-24  4.554808  1.552753  1.345575  2.336518                2.286682
# 2020-09-25  4.658597  1.563379  1.349187  2.363788                2.311827
# 2020-09-28  4.694911  1.578942  1.327815  2.395786                2.320754
# 2020-09-29  4.646043  1.578405  1.305539  2.403655                2.306690
# 2020-09-30  4.714862  1.597939  1.288682  2.404096                2.315028

# %% [markdown]
# #### It can be seen that this suggest that the portfolio has given cummulative return of 2.31 % in the given period.

# %%
# Lets Plot the graph

plt.figure(figsize=(16,8))
plt.plot(daily_cumulative_return['portfolio_daily_return'], label = 'Daily Returns')
plt.title('Portfolio Daily Returns', fontsize = 20)
plt.legend(loc = 'best', fontsize = 20)
plt.show()

# %% [markdown]
# ### Portfolio Risk:
# - For the portfolio standard deviation formula, we need three elements:
#
#     - Portfolio weighted array
#     - Portfolio covariance matrix
#     - Transpose of portfolio weight array
# - The weight for each stock in the portfolio is already abailable. We need to calculate the daily covariance. Remember, the covariance must be annualised by **multiplying with 252 (the trading days in a year).**

# %%
# Covariance matrix for the portfolio
# Removing the last column (Portfolio_Daily_Return) from our calculation.

covariance_matrix_portfolio_s = stocks_returns_daily.iloc[:,:-1]
covariance_matrix_portfolio_s = (covariance_matrix_portfolio_s.cov())*252

covariance_matrix_portfolio_s
# Out:
#            MSFT       JNJ     RHHBY      GOOG
# MSFT   0.077524  0.028277  0.029796  0.057110
# JNJ    0.028277  0.039117  0.019560  0.023301
# RHHBY  0.029796  0.019560  0.046023  0.023277
# GOOG   0.057110  0.023301  0.023277  0.068777

# %%
# Applying the matrix operations mentioned in the image above:

portfolio_variance_s = np.dot(initial_weight_stocks_df.T,np.dot(covariance_matrix_portfolio_s, initial_weight_stocks_df))

# %%
# Standard deviation (risk of portfolio):

portfolio_risk_s= np.sqrt(portfolio_variance_s)
portfolio_risk_s*100
# Out:
# 19.269220959046514

# %% [markdown]
# ## Sharpe Ratio:

# %%
# Assuming that the risk free rate is zero:

Sharpe_Ratio_S = (stocks_returns_daily['portfolio_daily_return'].mean() - daily_return['S&P500'].mean())/ stocks_returns_daily['portfolio_daily_return'].std()
Sharpe_Ratio_S
# Out:
# 0.01842112070755877

# %%
#Let's Calculate Annualised sharpe ratio:

Annualised_Sharpe_Ratio_S = (252**0.5)*Sharpe_Ratio_S
Annualised_Sharpe_Ratio_S
# Out:
# 0.2924262255798162

# %% [markdown]
# ## Total ROI (Return On Investment) from the Portfolio:

# %%
# calculating the total return on investment:

invested_amount    = 500000
Cummulative_return = daily_cumulative_return['portfolio_daily_return'][-1]
Expected_Return    = round(invested_amount*Cummulative_return,2)
Expected_Earning   = round(Expected_Return-invested_amount,2)
print(f"""Invested Amount : {invested_amount}
         Expected Retunr  : {Expected_Return}
         Expected Earning : {Expected_Earning}""")
# Out:
# Invested Amount : 500000
#          Expected Retunr  : 1157514.11
#          Expected Earning : 657514.11

# %% [markdown]
# ### Final Results:
# - As Mr.Patrick Jyengar invests 5 Hundred Thousand Dollar in equities. The returns that he would get after 5 years of time period is 1.15 Million Dollar with more than 6 Hundred Thousand dollars of gain.
#
#
# #### same process will be applied for second client:
#
#
# # PORTFOLIO ANAlYSIS:
#
# ### Mr. Peter Jyengar Portfolio:
# - Mr. Peter Jyengar on the other hand Consistent with his attitude towards risk, he prefers high-return investments. Believes that he can still bounce back in case of any occasional losses.
# - He Wants to invest 1 million dollar from company's cash and cash equivalents in the most high-margin stocks Expects high returns within 5 years for inorganic expansion of his company.
# - As per his profile High risk/High Returns stocks like AMZN, MSFT and AAPL is suitable to invest on.
# - Overall returns with these stocks would fetch him Maximum returns and also cater the Risk.

# %%
# Initial weights of stocks for the data :

stocks_data1= ['AMZN','MSFT','AAPL']

# stocks weight :
initial_weight_stocks_df1= np.array([0.334,0.334,0.332])

# %%
# create the dataset for the selected data:

stocks1=stocks_original['10-01-2015':]
portfolio1=stocks1.copy()
portfolio1 =portfolio1[stocks_data1]
portfolio1.tail()
# Out:
#                    AMZN        MSFT        AAPL
# Date
# 2020-09-24  3019.790039  203.190002  108.220001
# 2020-09-25  3095.129883  207.820007  112.279999
# 2020-09-28  3174.050049  209.440002  114.959999
# 2020-09-29  3144.879883  207.259995  114.089996
# 2020-09-30  3148.729980  210.330002  115.809998

# %% [markdown]
# # Stocks return on daily basis :

# %%
stocks_daily_return1 = portfolio1.pct_change()
stocks_daily_return1.head()
# Out:
#                 AMZN      MSFT      AAPL
# Date
# 2015-10-01       NaN       NaN       NaN
# 2015-10-02  0.022699  0.021520  0.007301
# 2015-10-05  0.020919  0.023261  0.003624
# 2015-10-06 -0.011404  0.002573  0.004784
# 2015-10-07  0.008298  0.001069 -0.004761

# %% [markdown]
# # Average daily return of stock :

# %%
avg_stocks_daily_return1=stocks_daily_return1.mean()
avg_stocks_daily_return1.head()
# Out:
# AMZN    0.001611
# MSFT    0.001387
# AAPL    0.001322
# dtype: float64

# %% [markdown]
# # Risk of stocks in portfolio:

# %%
stocks_risk1 = stocks_daily_return1.std()
stocks_risk1
# Out:
# AMZN    0.018969
# MSFT    0.017539
# AAPL    0.018729
# dtype: float64

# %%
avg_risk = stocks_risk1.mean()
avg_risk_per=avg_risk*100
print(round(avg_risk_per,3),"%")
# Out:
# 1.841 %

# %% [markdown]
# # Daily return from the portfolio:

# %%
stocks_daily_return1['Daily_portfolio_return1']= stocks_daily_return1.dot(initial_weight_stocks_df1)
stocks_daily_return1.head()
# Out:
#                 AMZN      MSFT      AAPL  Daily_portfolio_return1
# Date
# 2015-10-01       NaN       NaN       NaN                      NaN
# 2015-10-02  0.022699  0.021520  0.007301                 0.017193
# 2015-10-05  0.020919  0.023261  0.003624                 0.015959
# 2015-10-06 -0.011404  0.002573  0.004784                -0.001361
# 2015-10-07  0.008298  0.001069 -0.004761                 0.001548

# %% [markdown]
# # Total Portfolio Return:

# %%
allocated_stocks_return_daily = (initial_weight_stocks_df1*avg_stocks_daily_return1)
allocated_stocks_return_daily.head()
# Out:
# AMZN    0.000538
# MSFT    0.000463
# AAPL    0.000439
# dtype: float64

# %% [markdown]
# ### The Average Daily Returns of Portfolio is 0.13%

# %%
# Lets Plot the graph
plt.figure(figsize=(16,8))
stocks_daily_return1['Daily_portfolio_return1'].plot()
plt.title('Daily_portfolio_return1', fontsize = 20)
plt.legend(loc = 'best', fontsize = 15)
plt.xticks(rotation=0)
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # Cumulative return from portfolio:

# %%
daily_cumulative_return1= (1+stocks_daily_return1).cumprod()
daily_cumulative_return1.tail(5)
# Out:
#                 AMZN      MSFT      AAPL  Daily_portfolio_return1
# Date
# 2020-09-24  5.799259  4.554808  3.950356                 4.948047
# 2020-09-25  5.943943  4.658597  4.098558                 5.088566
# 2020-09-28  6.095503  4.694911  4.196386                 5.185475
# 2020-09-29  6.039484  4.646043  4.164628                 5.138502
# 2020-09-30  6.046878  4.714862  4.227414                 5.191744

# %% [markdown]
# ### This shows that portfolio has given cumulative return of  **4.59%** in the given period

# %%
# lets plot the graph for the :

plt.figure(figsize=(16,8))
plt.plot(daily_cumulative_return1['Daily_portfolio_return1'],label ='Daily Returns')
plt.title("Portfolio daily returns")
plt.legend(loc ='best',fontsize=20)
plt.show()

# %% [markdown]
# # PORTFOLIO RISK:
#
# - For the portfolio standard deviation formula, we need three elements :
#
# 1. Portfolio weighted array
# 2. Portfolio covariance matrix
# 3. Transpose of portfolio  weighted array
#
# - The weight for each stock in the portfolio is already abailable. We need to calculate the daily covariance. Remember, the covariance must be annualised by multiplying with 252 (the trading days in a year).
#
#
# **1.covariance matix for the portfolio:**

# %%
covariance_portfolio_matrix_s1 = stocks_daily_return1.iloc[:,:-1]
covariance_portfolio_matrix_s1 = (covariance_portfolio_matrix_s1.cov())*252
covariance_portfolio_matrix_s1
# Out:
#           AMZN      MSFT      AAPL
# AMZN  0.090671  0.056626  0.051597
# MSFT  0.056626  0.077524  0.058350
# AAPL  0.051597  0.058350  0.088398

# %% [markdown]
# **2.Portfolio covarince matrix:**

# %%
portfolio_variance_s = np.dot(initial_weight_stocks_df1.T, np.dot(covariance_portfolio_matrix_s1,initial_weight_stocks_df1))
portfolio_variance_s
# Out:
# 0.0655242733780793

# %% [markdown]
# **3. Standard deviation (risk of portfolio):**

# %%
portfolio_risk=np.sqrt(portfolio_variance_s)
portfolio_risk*100
# Out:
# 25.597709541691284

# %% [markdown]
# # sharpe ratio :

# %%
sharpe_ratio_s =(stocks_daily_return1['Daily_portfolio_return1'].mean() - daily_return['S&P500'].mean())/stocks_daily_return1['Daily_portfolio_return1'].std()
sharpe_ratio_s
# Out:
# 0.05721898174183326

# %% [markdown]
# ### Annual sharpe ratio :

# %%
annual_sharpe_ratio_s = (252**0.5)*sharpe_ratio_s
annual_sharpe_ratio_s
# Out:
# 0.9083231757674173

# %% [markdown]
# # Total ROI (Return On Investment) from the Portfolio:
#
# #### Calculating the total return on investment :

# %%
invested_amount = 1000000
cumulative_return = daily_cumulative_return1['Daily_portfolio_return1'][-1]
expected_return = round(invested_amount*cumulative_return,2)
expected_earning = round(expected_return-invested_amount,2)

print(f"""Invested Amount : {invested_amount}
Expected Return : {expected_return}
Expected Earning : {expected_earning}""")
# Out:
# Invested Amount : 1000000
# Expected Return : 5191744.34
# Expected Earning : 4191744.34

# %% [markdown]
# # Final  Results :
#
# **As Mr. Peter Jyengar invests 1 Million Dollars in equities. The returns that he would get after 5 years of time period is more than 5 Million Dollars with more than 4 Million Dollars of gain.**

# %% [markdown]
# **---------------------------------------------------- END------------------------------------------------------------------------------------------------------**
